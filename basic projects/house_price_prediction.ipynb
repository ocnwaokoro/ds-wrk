# %% [markdown]
# ### Import the necessary Python libraries and the dataset

# %%
import pandas as pd
housing = pd.read_csv("housing.csv")
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
housing.ocean_proximity.value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %% [markdown]
# ### Histogram for each numerical attribute

# %%
import matplotlib.pyplot as plt
housing.hist(bins=50, figsize=(10, 8))
plt.show()

# %% [markdown]
# ### Split the data into training and test sets

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(housing, test_size=0.2, random_state=42)

# %% [markdown]
# ### Split data into different strata based on median income

# %%
import numpy as np
housing['income_cat'] = pd.cut(housing['median_income'], bins=[0., 1.5, 3.0, 4.5, 6., np.inf], labels=[1, 2, 3, 4, 5])
housing['income_cat'].hist()
plt.show()

# %% [markdown]
# ### Perform stratified sampling

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2)
# split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_index, test_index in split.split(housing, housing["income_cat"]):
    strat_train_set = housing.loc[train_index]
    strat_test_set = housing.loc[test_index]
print(strat_test_set['income_cat'].value_counts() / len(strat_test_set))
# Out:
# 3    0.350533
# 2    0.318798
# 4    0.176357
# 5    0.114341
# 1    0.039971
# Name: income_cat, dtype: float64

# %% [markdown]
# ### Remove the income_cat attribute to get the data back to its form

# %%
for set_ in (strat_train_set, strat_test_set):
    set_.drop('income_cat', axis=1, inplace=True)
housing = strat_train_set.copy()

# %% [markdown]
# ### Visualize the data in terms of longitude and latitude

# %%
housing.plot(kind='scatter', x='longitude', y='latitude', alpha=0.4, s=housing['population']/100, label='population',
figsize=(12, 8), c='median_house_value', cmap=plt.get_cmap('jet'), colorbar=True)
plt.legend()
plt.show()

# %% [markdown]
# ### Calculate standard correlation coefficient between each pair of attributes

# %%
corr_matrix = housing.corr()
print(corr_matrix.median_house_value.sort_values(ascending=False))
# Out:
# median_house_value    1.000000
# median_income         0.685744
# total_rooms           0.136742
# housing_median_age    0.104708
# households            0.068696
# total_bedrooms        0.052600
# population           -0.021918
# longitude            -0.041268
# latitude             -0.148340
# Name: median_house_value, dtype: float64

# %% [markdown]
# ### Plots each numeric attribute against every other numeric attribute

# %%
keys = {housing.columns[i]: (i+1)  for i in range(len(housing.columns))}
boo = housing.rename(columns = keys)
boo = housing.copy()
axes = pd.plotting.scatter_matrix(boo, alpha=0.2)
for ax in axes.flatten():
    ax.xaxis.label.set_rotation(90)
    ax.yaxis.label.set_rotation(0)
    ax.yaxis.label.set_ha('right')
    ax.set_xticks([])
    ax.set_yticks([])
plt.tight_layout()
plt.gcf().subplots_adjust(wspace=0, hspace=0)
plt.show()

# %%
import seaborn as sns
sns.pairplot(boo)

# %% [markdown]
# ### Add 3 new columns to the dataset; rooms per household, bedrooms per room and population per household
# * based on correlation matrix

# %%
# these are over-generalizing averages
housing["rooms_per_household"] = housing["total_rooms"]/housing["households"]
housing["bedrooms_per_room"] = housing["total_bedrooms"]/housing["total_rooms"]
housing["population_per_household"] = housing["population"]/housing["households"]

corr_matrix = housing.corr()
print(corr_matrix["median_house_value"].sort_values(ascending=False))
# Out:
# median_house_value          1.000000
# median_income               0.685744
# rooms_per_household         0.149010
# total_rooms                 0.136742
# housing_median_age          0.104708
# households                  0.068696
# total_bedrooms              0.052600
# population                 -0.021918
# population_per_household   -0.022253
# longitude                  -0.041268
# latitude                   -0.148340
# bedrooms_per_room          -0.249393
# Name: median_house_value, dtype: float64

# %% [markdown]
# ### Perform all the necessary data transformations

# %%
# Data Preparation
housing = strat_train_set.drop("median_house_value", axis=1)
housing_labels = strat_train_set["median_house_value"].copy()

median = housing["total_bedrooms"].median()
housing["total_bedrooms"].fillna(median, inplace=True)

housing_num = housing.drop("ocean_proximity", axis=1)

from sklearn.base import BaseEstimator, TransformerMixin

# column index
rooms_ix, bedrooms_ix, population_ix, households_ix = 3, 4, 5, 6

class CombinedAttributesAdder(BaseEstimator, TransformerMixin):
    def __init__(self, add_bedrooms_per_room=True): # no *args or **kargs
        self.add_bedrooms_per_room = add_bedrooms_per_room
    def fit(self, X, y=None):
        return self  # nothing else to do
    def transform(self, X):
        rooms_per_household = X[:, rooms_ix] / X[:, households_ix]
        population_per_household = X[:, population_ix] / X[:, households_ix]
        if self.add_bedrooms_per_room:
            bedrooms_per_room = X[:, bedrooms_ix] / X[:, rooms_ix]
            return np.c_[X, rooms_per_household, population_per_household,
                         bedrooms_per_room]
        else:
            return np.c_[X, rooms_per_household, population_per_household]

# %% [markdown]
# ### Use Pipeline class to help with ordered transformations

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
num_pipeline = Pipeline([
    ('imputer',SimpleImputer(strategy="median")),
    ('attribs_adder', CombinedAttributesAdder()),
    ('std_scaler', StandardScaler()),
])
housing_num_tr = num_pipeline.fit_transform(housing_num)

from sklearn.compose import ColumnTransformer
num_attribs = list(housing_num)
cat_attribs = ["ocean_proximity"]
full_pipeline = ColumnTransformer([
    ("num", num_pipeline, num_attribs),
    ("cat", OneHotEncoder(), cat_attribs),
])
housing_prepared = full_pipeline.fit_transform(housing)

# %% [markdown]
# ### Use the linear regression algorithm for the task of house price prediction

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(housing_prepared, housing_labels)
to_show = 10

data = housing.iloc[:to_show]
labels = housing_labels.iloc[:to_show]
data_preparation = full_pipeline.transform(data)
print("Predictions: ", lin_reg.predict(data_preparation))
# Out:
# Predictions:  [246355.22857184 312282.35149386 217692.71365289 252029.63978583
#  118277.10349624 235947.06912087 364995.550405    45901.25487861
#  161109.06731484 201436.13822444]

# %%
a = pd.Series(labels.values)

b = pd.Series(lin_reg.predict(data_preparation))

c = pd.concat([a.astype(int),b.astype(int),abs(a-b).astype(int)], 
              axis = 1, keys=['real', 'predicted', 'difference'])
display(c)
# Out:
#      real  predicted  difference
# 0  221100     246355       25255
# 1  196400     312282      115882
# 2  142000     217692       75692
# 3  135400     252029      116629
# 4  116000     118277        2277
# 5  197000     235947       38947
# 6  343300     364995       21695
# 7  119200      45901       73298
# 8  208300     161109       47190
# 9  202800     201436        1363
