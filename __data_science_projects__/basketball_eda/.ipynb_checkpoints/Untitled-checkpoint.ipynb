# %%
import pandas as pd
import base64
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
year = 2022
url = f"https://www.basketball-reference.com/leagues/NBA_{year}_per_game.html"
html = pd.read_html(url, header=0)
df = html[0]
raw = df.drop(df[df['Age'] == 'Age'].index)
raw = raw.fillna(0)
playerstats = raw.drop(['Rk'], axis=1)
playerstats
# Out:
#                 Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...   FT%  \
# 0     Precious Achiuwa   C  22  TOR  73  28  23.6  3.6   8.3  .439  ...  .595
# 1         Steven Adams   C  28  MEM  76  75  26.3  2.8   5.1  .547  ...  .543
# 2          Bam Adebayo   C  24  MIA  56  56  32.6  7.3  13.0  .557  ...  .753
# 3         Santi Aldama  PF  21  MEM  32   0  11.3  1.7   4.1  .402  ...  .625
# 4    LaMarcus Aldridge   C  36  BRK  47  12  22.3  5.4   9.7  .550  ...  .873
# ..                 ...  ..  ..  ...  ..  ..   ...  ...   ...   ...  ...   ...
# 837     Thaddeus Young  PF  33  TOR  26   0  18.3  2.6   5.5  .465  ...  .481
# 838         Trae Young  PG  23  ATL  76  76  34.9  9.4  20.3  .460  ...  .904
# 839     Omer Yurtseven   C  23  MIA  56  12  12.6  2.3   4.4  .526  ...  .623
# 840        Cody Zeller   C  29  POR  27   0  13.1  1.9   3.3  .567  ...  .776
# 841        Ivica Zubac   C  24  LAC  76  76  24.4  4.1   6.5  .626  ...  .727
#
# ...

# %%
def load_data(year):
    url = f"https://www.basketball-reference.com/leagues/NBA_{year}_per_game.html"
    html = pd.read_html(url, header=0)
    df = html[0]
    raw = df.drop(df[df['Age'] == 'Age'].index)
    raw = raw.fillna(0)
    playerstats = raw.drop(['Rk'], axis=1)
    return playerstats

# %%
f"C,PF,SF,PG,SG".split(',')
# Out:
# ['C', 'PF', 'SF', 'PG', 'SG']

# %%
list(playerstats['Pos'].unique())
# Out:
# ['C',
#  'PF',
#  'SG',
#  'PG',
#  'SF',
#  'SG-PG',
#  'SG-SF',
#  'PG-SG',
#  'SF-SG',
#  'PF-SF',
#  'C-PF',
#  'PF-C',
#  'SG-PG-SF']

# %%
url = f"https://www.pro-football-reference.com/years/2022/rushing.htm"
html = pd.read_html(url, header=1)
df = html[0]
raw = df.drop(df[df['Age'] == 'Age'].index)
raw = raw.fillna(0)
playerstats = raw.drop(['Rk'], axis=1)
playerstats
# Out:
#                        Player   Tm Age Pos   G  GS  Att   Yds  TD  1D Lng  \
# 0             Derrick Henry *  TEN  28  RB  15  15  319  1429  13  64  56
# 1                Josh Jacobs*  LVR  24  RB  15  15  306  1539  11  86  86
# 2             Saquon Barkley*  NYG  25  RB  15  15  283  1254  10  60  68
# 3                 Nick Chubb*  CLE  27  RB  15  15  276  1344  12  61  41
# 4                 Dalvin Cook  MIN  27  RB  15  15  244  1109   8  47  81
# ..                        ...  ...  ..  ..  ..  ..  ...   ...  ..  ..  ..
# 344          Courtland Sutton  DEN  27  WR  13  13    1     5   0   0   5
# 345           Deven Thompkins  TAM  23  WR   3   0    1     9   0   0   9
# 346  Marquez Valdes-Scantling  KAN  28  WR  15   9    1    -3   0   0  -3
# 347        Cedrick Wilson Jr.  MIA  27  WR  14   0    1     8   0   0   8
# 348          Michael Woods II  CLE  22  WR   8   0    1    -5   0   0  -5
#
#       Y/A    Y/G Fmb
# 0     4.5   95.3   6
# 1     5.0  102.6   3
# ...

# %%
for h in html:
    display(h)
# Out:
#       Rk                    Player   Tm Age Pos   G  GS  Att   Yds  TD  1D  \
# 0      1           Derrick Henry *  TEN  28  RB  15  15  319  1429  13  64
# 1      2              Josh Jacobs*  LVR  24  RB  15  15  306  1539  11  86
# 2      3           Saquon Barkley*  NYG  25  RB  15  15  283  1254  10  60
# 3      4               Nick Chubb*  CLE  27  RB  15  15  276  1344  12  61
# 4      5               Dalvin Cook  MIN  27  RB  15  15  244  1109   8  47
# ..   ...                       ...  ...  ..  ..  ..  ..  ...   ...  ..  ..
# 344  334          Courtland Sutton  DEN  27  WR  13  13    1     5   0   0
# 345  335           Deven Thompkins  TAM  23  WR   3   0    1     9   0   0
# 346  336  Marquez Valdes-Scantling  KAN  28  WR  15   9    1    -3   0   0
# 347  337        Cedrick Wilson Jr.  MIA  27  WR  14   0    1     8   0   0
# 348  338          Michael Woods II  CLE  22  WR   8   0    1    -5   0   0
#
#     Lng   Y/A    Y/G Fmb
# 0    56   4.5   95.3   6
# ...

# %%
html[0].Tm.unique()
# Out:
# array(['TOR', 'MEM', 'MIA', 'BRK', 'TOT', 'NOP', 'UTA', 'MIL', 'CLE',
#        'IND', 'LAL', 'ORL', 'NYK', 'HOU', 'WAS', 'Tm', 'PHO', 'SAC',
#        'DET', 'CHO', 'CHI', 'ATL', 'DEN', 'PHI', 'SAS', 'LAC', 'OKC',
#        'MIN', 'DAL', 'GSW', 'POR', 'BOS'], dtype=object)

# %%
f"Passing,Rushing,Receiving,Scrimmage Stats,Defense,Kicking,Punting,Kick & Punt Returns,Scoring".split(',')
# Out:
# ['passing',
#  'rushing',
#  'receiving',
#  'scrimmage stats',
#  'defense',
#  'kicking',
#  'punting',
#  'kick & punt returns',
#  'scoring']
